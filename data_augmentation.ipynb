# %%
# !pip install arabic-reshaper>=3.0.0 python-bidi opencv-python pillow numpy tqdm diffimg

# %%
# !pip install trdg --no-deps

# %%
pip install wikipedia diffimg datasets

# %%
# !python -m trdg.run -i corpus_viet.txt \
    -f 64 \
    -l vi \
    -fd ./fonts_viet \
    -c 10 \
    -w 8 \
    --output_dir ./synthetic_data
